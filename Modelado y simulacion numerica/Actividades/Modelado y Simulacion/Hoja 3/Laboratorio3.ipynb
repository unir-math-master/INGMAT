# %% [markdown]
# Laboratorio No. 3 Modelado y Simulacion Numerica.

# %% [markdown]
# Importacion de librerias.

# %%
import random
import math
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter
import seaborn as sns

# %% [markdown]
# Inicializacion de constantes.

# %%
total_eventos = 100
cola = []
lambda_valle = 7
lambda_punta = 1

# %% [markdown]
# Generacion de numeros aleatorios exponenciales para llegadas de clientes.

# %%
def genera_tiempo_cliente(lam):
    return round(-math.log(random.uniform(0,1))/lam, 2)

# %% [markdown]
# Generacion de numeros aleatorios discretos para atencion de operadores.

# %%
def generador_operador(op):
    r = random.uniform(0,1)
    if(op==1):
        if(r>=0 and r<0.3):
            output = 2
        elif(r>=0.3 and r<0.5):
            output = 2.5
        elif(r>=0.5 and r<0.75):
            output = 3
        elif(r>=0.75 and r<1):
            output = 4
    if(op==2):
        if(r>=0 and r<0.15):
            output = 2
        elif(r>=0.15 and r<0.30):
            output = 2.5
        elif(r>=0.30 and r<0.70):
            output = 3
        elif(r>=0.70 and r<0.90):
            output = 3.5
        elif(r>=0.90 and r<1):
            output = 4
    return output

# %%
x = []
tiempos_clientes_valle = []
tiempos_clientes_s = []

for i in range(0,total_eventos):
    al = genera_tiempo_cliente(1/lambda_valle)
    tiempos_clientes_s.append(al)
    tiempos_clientes_valle.append(al)
    x.append(i)
tiempos_clientes_s.sort()

plt.plot(x,tiempos_clientes_s)

# %%
x = []
tiempos_clientes_punta = []
tiempos_clientes_s = []

for i in range(0,total_eventos):
    al = genera_tiempo_cliente(1/lambda_punta)
    tiempos_clientes_s.append(al)
    tiempos_clientes_punta.append(al)
    x.append(i)
tiempos_clientes_s.sort()
plt.plot(x,tiempos_clientes_s)

# %%
tiempos_operador_1 = []
for i in range(0,total_eventos):
    tiempos_operador_1.append(generador_operador(1))

Elements = Counter(tiempos_operador_1)
plt.plot([2,2.5,3,3.5,4],[Elements[2],Elements[2.5],Elements[3],Elements[3.5],Elements[4]], 'ro')

# %%
tiempos_operador_2 = []
for i in range(0,total_eventos):
    tiempos_operador_2.append(generador_operador(2))

Elements = Counter(tiempos_operador_2)
plt.plot([2,2.5,3,3.5,4],[Elements[2],Elements[2.5],Elements[3],Elements[3.5],Elements[4]], 'ro')

# %% [markdown]
# Script para generacion de vector con tiempos aleatorios sumados posicion a posicion.

# %%
temp = 0
tiempo_llegada_clientes = []
for i in range(0,total_eventos):
    temp = temp + tiempos_clientes_valle[i] 
    tiempo_llegada_clientes.append(round(temp,2))
print(tiempo_llegada_clientes)
# Out:
# [19.82, 21.63, 48.14, 52.42, 66.18, 68.98, 78.57, 86.37, 95.16, 98.59, 101.17, 110.53, 112.62, 116.96, 122.13, 122.63, 123.13, 123.86, 124.7, 139.04, 145.72, 149.69, 166.14, 185.93, 200.98, 214.87, 224.01, 236.68, 248.16, 250.53, 256.4, 267.07, 295.25, 298.27, 301.64, 313.21, 317.04, 320.53, 326.33, 337.68, 349.21, 352.75, 354.29, 357.11, 362.9, 367.49, 367.53, 374.62, 394.19, 399.36, 410.84, 424.05, 425.96, 428.4, 430.98, 443.04, 446.22, 452.39, 453.65, 453.68, 457.19, 464.56, 484.74, 501.4, 512.95, 515.96, 516.25, 522.42, 531.34, 532.4, 537.39, 552.52, 555.54, 561.04, 561.08, 570.12, 573.48, 575.42, 577.95, 588.99, 590.27, 593.46, 613.2, 613.24, 628.45, 629.45, 631.32, 640.1, 660.19, 684.69, 694.05, 697.59, 701.68, 720.88, 730.1, 733.34, 735.62, 740.23, 741.44, 746.08]

# %% [markdown]
# Script para generacion de datos con operador 1.

# %%
def get_time(cola):
    return cola.get('Minuto')

def duplicates(lst, item):
    return [i for i, x in enumerate(lst) if x == item]

datos = []
vector_cola = []
ocupacion_operador_1 = 0
vector_if = []
promedio_cola = 0

for i in range(0, total_eventos):
    t_l = tiempo_llegada_clientes[i]
    t_o = tiempos_operador_1[i]
    h_s = round(tiempo_llegada_clientes[i] + tiempos_operador_1[i],2)
    ocupacion_operador_1 = ocupacion_operador_1 + t_o

    vector_cola.append({'Minuto': t_l, 'Cliente': i, 'Estado':'Inicio'})
    vector_cola.append({'Minuto': h_s, 'Cliente': i, 'Estado':'Fin'})

#for i in range(0,total_eventos):
#    if vector_cola[i]['Estado'] == 'Inicio':
#        vector_if.append('I')
#    if vector_cola[i]['Estado'] == 'Fin':
#        vector_if.append('F')

#ordenar para luego agregar cola
vector_cola.sort(key=get_time)
cola = -1
cola_array = []
for i in range(0,2*total_eventos):
    if vector_cola[i]['Estado'] == 'Inicio':
        cola = cola+1
        vector_cola[i]['Cola'] = cola
        cola_array.append(cola)
        promedio_cola = cola*vector_cola[i]['Minuto']
    if vector_cola[i]['Estado'] == 'Fin':
        cola = cola-1
    #print(vector_cola[i])

#print(duplicates(vector_if, "F"))

#porcentaje de ocupacion de operador 1
Porcentaje_ocupacion = round((ocupacion_operador_1*100)/(vector_cola[len(vector_cola)-1]['Minuto'] - vector_cola[0]['Minuto']),2)
promedio_cola = round(promedio_cola/(vector_cola[len(vector_cola)-1]['Minuto'] - vector_cola[0]['Minuto']),2)

print(sum(cola_array)/len(cola_array))
print(Porcentaje_ocupacion)
print(promedio_cola )

plt.plot(cola_array)
ax = sns.displot(cola_array, rug=True)
# Out:
# {'Minuto': 19.82, 'Cliente': 0, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 21.63, 'Cliente': 1, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 21.82, 'Cliente': 0, 'Estado': 'Fin'}
# {'Minuto': 23.63, 'Cliente': 1, 'Estado': 'Fin'}
# {'Minuto': 48.14, 'Cliente': 2, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 50.14, 'Cliente': 2, 'Estado': 'Fin'}
# {'Minuto': 52.42, 'Cliente': 3, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 55.42, 'Cliente': 3, 'Estado': 'Fin'}
# {'Minuto': 66.18, 'Cliente': 4, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 68.98, 'Cliente': 5, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 70.18, 'Cliente': 4, 'Estado': 'Fin'}
# {'Minuto': 71.48, 'Cliente': 5, 'Estado': 'Fin'}
# {'Minuto': 78.57, 'Cliente': 6, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 82.57, 'Cliente': 6, 'Estado': 'Fin'}
# {'Minuto': 86.37, 'Cliente': 7, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 90.37, 'Cliente': 7, 'Estado': 'Fin'}
# {'Minuto': 95.16, 'Cliente': 8, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 97.16, 'Cliente': 8, 'Estado': 'Fin'}
# {'Minuto': 98.59, 'Cliente': 9, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 101.17, 'Cliente': 10, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 101.59, 'Cliente': 9, 'Estado': 'Fin'}
# {'Minuto': 105.17, 'Cliente': 10, 'Estado': 'Fin'}
# {'Minuto': 110.53, 'Cliente': 11, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 112.62, 'Cliente': 12, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 113.53, 'Cliente': 11, 'Estado': 'Fin'}
# {'Minuto': 114.62, 'Cliente': 12, 'Estado': 'Fin'}
# {'Minuto': 116.96, 'Cliente': 13, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 119.96, 'Cliente': 13, 'Estado': 'Fin'}
# {'Minuto': 122.13, 'Cliente': 14, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 122.63, 'Cliente': 15, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 123.13, 'Cliente': 16, 'Estado': 'Inicio', 'Cola': 2}
# {'Minuto': 123.86, 'Cliente': 17, 'Estado': 'Inicio', 'Cola': 3}
# {'Minuto': 124.7, 'Cliente': 18, 'Estado': 'Inicio', 'Cola': 4}
# {'Minuto': 125.63, 'Cliente': 16, 'Estado': 'Fin'}
# {'Minuto': 125.86, 'Cliente': 17, 'Estado': 'Fin'}
# {'Minuto': 126.13, 'Cliente': 14, 'Estado': 'Fin'}
# {'Minuto': 126.63, 'Cliente': 15, 'Estado': 'Fin'}
# {'Minuto': 127.2, 'Cliente': 18, 'Estado': 'Fin'}
# {'Minuto': 139.04, 'Cliente': 19, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 142.04, 'Cliente': 19, 'Estado': 'Fin'}
# {'Minuto': 145.72, 'Cliente': 20, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 149.69, 'Cliente': 21, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 149.72, 'Cliente': 20, 'Estado': 'Fin'}
# {'Minuto': 152.19, 'Cliente': 21, 'Estado': 'Fin'}
# {'Minuto': 166.14, 'Cliente': 22, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 169.14, 'Cliente': 22, 'Estado': 'Fin'}
# {'Minuto': 185.93, 'Cliente': 23, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 188.43, 'Cliente': 23, 'Estado': 'Fin'}
# {'Minuto': 200.98, 'Cliente': 24, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 204.98, 'Cliente': 24, 'Estado': 'Fin'}
# {'Minuto': 214.87, 'Cliente': 25, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 216.87, 'Cliente': 25, 'Estado': 'Fin'}
# {'Minuto': 224.01, 'Cliente': 26, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 227.01, 'Cliente': 26, 'Estado': 'Fin'}
# {'Minuto': 236.68, 'Cliente': 27, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 239.68, 'Cliente': 27, 'Estado': 'Fin'}
# {'Minuto': 248.16, 'Cliente': 28, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 250.53, 'Cliente': 29, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 252.16, 'Cliente': 28, 'Estado': 'Fin'}
# {'Minuto': 253.03, 'Cliente': 29, 'Estado': 'Fin'}
# {'Minuto': 256.4, 'Cliente': 30, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 259.4, 'Cliente': 30, 'Estado': 'Fin'}
# {'Minuto': 267.07, 'Cliente': 31, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 270.07, 'Cliente': 31, 'Estado': 'Fin'}
# {'Minuto': 295.25, 'Cliente': 32, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 298.27, 'Cliente': 33, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 299.25, 'Cliente': 32, 'Estado': 'Fin'}
# {'Minuto': 300.27, 'Cliente': 33, 'Estado': 'Fin'}
# {'Minuto': 301.64, 'Cliente': 34, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 304.14, 'Cliente': 34, 'Estado': 'Fin'}
# {'Minuto': 313.21, 'Cliente': 35, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 315.71, 'Cliente': 35, 'Estado': 'Fin'}
# {'Minuto': 317.04, 'Cliente': 36, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 319.04, 'Cliente': 36, 'Estado': 'Fin'}
# {'Minuto': 320.53, 'Cliente': 37, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 323.53, 'Cliente': 37, 'Estado': 'Fin'}
# {'Minuto': 326.33, 'Cliente': 38, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 328.33, 'Cliente': 38, 'Estado': 'Fin'}
# {'Minuto': 337.68, 'Cliente': 39, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 340.68, 'Cliente': 39, 'Estado': 'Fin'}
# {'Minuto': 349.21, 'Cliente': 40, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 351.21, 'Cliente': 40, 'Estado': 'Fin'}
# {'Minuto': 352.75, 'Cliente': 41, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 354.29, 'Cliente': 42, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 354.75, 'Cliente': 41, 'Estado': 'Fin'}
# {'Minuto': 357.11, 'Cliente': 43, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 358.29, 'Cliente': 42, 'Estado': 'Fin'}
# {'Minuto': 360.11, 'Cliente': 43, 'Estado': 'Fin'}
# {'Minuto': 362.9, 'Cliente': 44, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 364.9, 'Cliente': 44, 'Estado': 'Fin'}
# {'Minuto': 367.49, 'Cliente': 45, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 367.53, 'Cliente': 46, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 369.99, 'Cliente': 45, 'Estado': 'Fin'}
# {'Minuto': 370.03, 'Cliente': 46, 'Estado': 'Fin'}
# {'Minuto': 374.62, 'Cliente': 47, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 378.62, 'Cliente': 47, 'Estado': 'Fin'}
# {'Minuto': 394.19, 'Cliente': 48, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 396.69, 'Cliente': 48, 'Estado': 'Fin'}
# {'Minuto': 399.36, 'Cliente': 49, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 401.86, 'Cliente': 49, 'Estado': 'Fin'}
# {'Minuto': 410.84, 'Cliente': 50, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 412.84, 'Cliente': 50, 'Estado': 'Fin'}
# {'Minuto': 424.05, 'Cliente': 51, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 425.96, 'Cliente': 52, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 427.96, 'Cliente': 52, 'Estado': 'Fin'}
# {'Minuto': 428.05, 'Cliente': 51, 'Estado': 'Fin'}
# {'Minuto': 428.4, 'Cliente': 53, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 430.4, 'Cliente': 53, 'Estado': 'Fin'}
# {'Minuto': 430.98, 'Cliente': 54, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 433.48, 'Cliente': 54, 'Estado': 'Fin'}
# {'Minuto': 443.04, 'Cliente': 55, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 445.04, 'Cliente': 55, 'Estado': 'Fin'}
# {'Minuto': 446.22, 'Cliente': 56, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 448.22, 'Cliente': 56, 'Estado': 'Fin'}
# {'Minuto': 452.39, 'Cliente': 57, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 453.65, 'Cliente': 58, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 453.68, 'Cliente': 59, 'Estado': 'Inicio', 'Cola': 2}
# {'Minuto': 454.89, 'Cliente': 57, 'Estado': 'Fin'}
# {'Minuto': 455.65, 'Cliente': 58, 'Estado': 'Fin'}
# {'Minuto': 456.18, 'Cliente': 59, 'Estado': 'Fin'}
# {'Minuto': 457.19, 'Cliente': 60, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 460.19, 'Cliente': 60, 'Estado': 'Fin'}
# {'Minuto': 464.56, 'Cliente': 61, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 467.06, 'Cliente': 61, 'Estado': 'Fin'}
# {'Minuto': 484.74, 'Cliente': 62, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 488.74, 'Cliente': 62, 'Estado': 'Fin'}
# {'Minuto': 501.4, 'Cliente': 63, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 503.9, 'Cliente': 63, 'Estado': 'Fin'}
# {'Minuto': 512.95, 'Cliente': 64, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 515.96, 'Cliente': 65, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 516.25, 'Cliente': 66, 'Estado': 'Inicio', 'Cola': 2}
# {'Minuto': 516.95, 'Cliente': 64, 'Estado': 'Fin'}
# {'Minuto': 517.96, 'Cliente': 65, 'Estado': 'Fin'}
# {'Minuto': 518.75, 'Cliente': 66, 'Estado': 'Fin'}
# {'Minuto': 522.42, 'Cliente': 67, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 526.42, 'Cliente': 67, 'Estado': 'Fin'}
# {'Minuto': 531.34, 'Cliente': 68, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 532.4, 'Cliente': 69, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 534.34, 'Cliente': 68, 'Estado': 'Fin'}
# {'Minuto': 534.4, 'Cliente': 69, 'Estado': 'Fin'}
# {'Minuto': 537.39, 'Cliente': 70, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 539.39, 'Cliente': 70, 'Estado': 'Fin'}
# {'Minuto': 552.52, 'Cliente': 71, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 555.02, 'Cliente': 71, 'Estado': 'Fin'}
# {'Minuto': 555.54, 'Cliente': 72, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 559.54, 'Cliente': 72, 'Estado': 'Fin'}
# {'Minuto': 561.04, 'Cliente': 73, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 561.08, 'Cliente': 74, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 563.04, 'Cliente': 73, 'Estado': 'Fin'}
# {'Minuto': 563.08, 'Cliente': 74, 'Estado': 'Fin'}
# {'Minuto': 570.12, 'Cliente': 75, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 573.48, 'Cliente': 76, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 574.12, 'Cliente': 75, 'Estado': 'Fin'}
# {'Minuto': 575.42, 'Cliente': 77, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 575.98, 'Cliente': 76, 'Estado': 'Fin'}
# {'Minuto': 577.95, 'Cliente': 78, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 578.42, 'Cliente': 77, 'Estado': 'Fin'}
# {'Minuto': 579.95, 'Cliente': 78, 'Estado': 'Fin'}
# {'Minuto': 588.99, 'Cliente': 79, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 590.27, 'Cliente': 80, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 590.99, 'Cliente': 79, 'Estado': 'Fin'}
# {'Minuto': 592.27, 'Cliente': 80, 'Estado': 'Fin'}
# {'Minuto': 593.46, 'Cliente': 81, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 595.46, 'Cliente': 81, 'Estado': 'Fin'}
# {'Minuto': 613.2, 'Cliente': 82, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 613.24, 'Cliente': 83, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 615.24, 'Cliente': 83, 'Estado': 'Fin'}
# {'Minuto': 617.2, 'Cliente': 82, 'Estado': 'Fin'}
# {'Minuto': 628.45, 'Cliente': 84, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 629.45, 'Cliente': 85, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 631.32, 'Cliente': 86, 'Estado': 'Inicio', 'Cola': 2}
# {'Minuto': 632.45, 'Cliente': 84, 'Estado': 'Fin'}
# {'Minuto': 633.45, 'Cliente': 85, 'Estado': 'Fin'}
# {'Minuto': 633.82, 'Cliente': 86, 'Estado': 'Fin'}
# {'Minuto': 640.1, 'Cliente': 87, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 643.1, 'Cliente': 87, 'Estado': 'Fin'}
# {'Minuto': 660.19, 'Cliente': 88, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 662.69, 'Cliente': 88, 'Estado': 'Fin'}
# {'Minuto': 684.69, 'Cliente': 89, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 688.69, 'Cliente': 89, 'Estado': 'Fin'}
# {'Minuto': 694.05, 'Cliente': 90, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 696.05, 'Cliente': 90, 'Estado': 'Fin'}
# {'Minuto': 697.59, 'Cliente': 91, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 700.59, 'Cliente': 91, 'Estado': 'Fin'}
# {'Minuto': 701.68, 'Cliente': 92, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 704.68, 'Cliente': 92, 'Estado': 'Fin'}
# {'Minuto': 720.88, 'Cliente': 93, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 722.88, 'Cliente': 93, 'Estado': 'Fin'}
# {'Minuto': 730.1, 'Cliente': 94, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 733.1, 'Cliente': 94, 'Estado': 'Fin'}
# {'Minuto': 733.34, 'Cliente': 95, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 735.62, 'Cliente': 96, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 737.34, 'Cliente': 95, 'Estado': 'Fin'}
# {'Minuto': 739.62, 'Cliente': 96, 'Estado': 'Fin'}
# {'Minuto': 740.23, 'Cliente': 97, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 741.44, 'Cliente': 98, 'Estado': 'Inicio', 'Cola': 1}
# {'Minuto': 742.73, 'Cliente': 97, 'Estado': 'Fin'}
# {'Minuto': 745.44, 'Cliente': 98, 'Estado': 'Fin'}
# {'Minuto': 746.08, 'Cliente': 99, 'Estado': 'Inicio', 'Cola': 0}
# {'Minuto': 748.58, 'Cliente': 99, 'Estado': 'Fin'}
# 0.39
# 38.7
# 0.0

# %%
def get_time(cola):
    return cola.get('Minuto')

def duplicates(lst, item):
    return [i for i, x in enumerate(lst) if x == item]

datos = []
vector_cola = []
ocupacion_operador_2 = 0
vector_if = []
promedio_cola = 0

for i in range(0, total_eventos):
    t_l = tiempo_llegada_clientes[i]
    t_o = tiempos_operador_2[i]
    h_s = round(tiempo_llegada_clientes[i] + tiempos_operador_2[i],2)
    ocupacion_operador_2 = ocupacion_operador_2 + t_o

    vector_cola.append({'Minuto': t_l, 'Cliente': i, 'Estado':'Inicio'})
    vector_cola.append({'Minuto': h_s, 'Cliente': i, 'Estado':'Fin'})

#for i in range(0,total_eventos):
#    if vector_cola[i]['Estado'] == 'Inicio':
#        vector_if.append('I')
#    if vector_cola[i]['Estado'] == 'Fin':
#        vector_if.append('F')

#ordenar para luego agregar cola
vector_cola.sort(key=get_time)
cola = -1
cola_array = []
for i in range(0,2*total_eventos):
    if vector_cola[i]['Estado'] == 'Inicio':
        cola = cola+1
        vector_cola[i]['Cola'] = cola
        cola_array.append(cola)
        promedio_cola = cola*vector_cola[i]['Minuto']
    if vector_cola[i]['Estado'] == 'Fin':
        cola = cola-1
    #print(vector_cola[i])

#print(duplicates(vector_if, "F"))

#porcentaje de ocupacion de operador 2
Porcentaje_ocupacion = round((ocupacion_operador_2*100)/(vector_cola[len(vector_cola)-1]['Minuto'] - vector_cola[0]['Minuto']),2)
promedio_cola = round(promedio_cola/(vector_cola[len(vector_cola)-1]['Minuto'] - vector_cola[0]['Minuto']),2)

print(sum(cola_array)/len(cola_array))
print(Porcentaje_ocupacion)
print(promedio_cola )

plt.plot(cola_array)
ax = sns.displot(cola_array, rug=True)
# Out:
# 0.36
# 40.1
# 0.0

# %%
temp = 0
tiempo_llegada_clientes = []
for i in range(0,total_eventos):
    temp = temp + tiempos_clientes_punta[i] 
    tiempo_llegada_clientes.append(round(temp,2))
print(tiempo_llegada_clientes)
# Out:
# [0.57, 1.45, 2.92, 4.43, 4.53, 5.63, 6.38, 6.92, 7.71, 8.41, 8.71, 9.08, 10.18, 10.22, 11.83, 12.29, 12.95, 13.53, 13.93, 14.14, 15.36, 15.64, 16.09, 16.34, 16.81, 17.11, 17.26, 17.37, 18.3, 18.51, 19.38, 19.59, 20.67, 20.86, 25.92, 26.54, 28.94, 30.49, 30.6, 30.61, 31.84, 32.22, 32.29, 35.03, 35.52, 38.38, 39.09, 39.47, 43.06, 43.62, 43.87, 44.71, 44.91, 45.99, 46.12, 47.35, 48.29, 48.57, 50.12, 51.14, 52.07, 54.1, 55.5, 56.39, 56.71, 56.71, 57.4, 58.5, 59.35, 59.95, 60.16, 60.43, 60.72, 61.62, 62.51, 63.1, 63.71, 63.84, 65.07, 65.67, 65.99, 66.2, 66.8, 68.6, 71.04, 71.33, 71.76, 71.84, 73.05, 73.44, 73.55, 75.81, 78.67, 79.67, 80.08, 80.62, 82.39, 84.31, 84.68, 86.55]

# %%
def get_time(cola):
    return cola.get('Minuto')

def duplicates(lst, item):
    return [i for i, x in enumerate(lst) if x == item]

datos = []
vector_cola = []
ocupacion_operador_1 = 0
vector_if = []
promedio_cola = 0

for i in range(0, total_eventos):
    t_l = tiempo_llegada_clientes[i]
    t_o = tiempos_operador_1[i]
    h_s = round(tiempo_llegada_clientes[i] + tiempos_operador_1[i],2)
    ocupacion_operador_1 = ocupacion_operador_1 + t_o

    vector_cola.append({'Minuto': t_l, 'Cliente': i, 'Estado':'Inicio'})
    vector_cola.append({'Minuto': h_s, 'Cliente': i, 'Estado':'Fin'})

#for i in range(0,total_eventos):
#    if vector_cola[i]['Estado'] == 'Inicio':
#        vector_if.append('I')
#    if vector_cola[i]['Estado'] == 'Fin':
#        vector_if.append('F')

#ordenar para luego agregar cola
vector_cola.sort(key=get_time)
cola = -1
cola_array = []
for i in range(0,2*total_eventos):
    if vector_cola[i]['Estado'] == 'Inicio':
        cola = cola+1
        vector_cola[i]['Cola'] = cola
        cola_array.append(cola)
        promedio_cola = cola*vector_cola[i]['Minuto']
    if vector_cola[i]['Estado'] == 'Fin':
        cola = cola-1
    #print(vector_cola[i])

#print(duplicates(vector_if, "F"))

#porcentaje de ocupacion de operador 1
Porcentaje_ocupacion = round((ocupacion_operador_1*100)/(vector_cola[len(vector_cola)-1]['Minuto'] - vector_cola[0]['Minuto']),2)
promedio_cola = round(promedio_cola/(vector_cola[len(vector_cola)-1]['Minuto'] - vector_cola[0]['Minuto']),2)

print(sum(cola_array)/len(cola_array))
print(Porcentaje_ocupacion)
print(promedio_cola )

plt.plot(cola_array)
ax = sns.displot(cola_array, rug=True)
# Out:
# 3.23
# 318.72
# 1.96

# %%
def get_time(cola):
    return cola.get('Minuto')

def duplicates(lst, item):
    return [i for i, x in enumerate(lst) if x == item]

datos = []
vector_cola = []
ocupacion_operador_2 = 0
vector_if = []
promedio_cola = 0

for i in range(0, total_eventos):
    t_l = tiempo_llegada_clientes[i]
    t_o = tiempos_operador_2[i]
    h_s = round(tiempo_llegada_clientes[i] + tiempos_operador_2[i],2)
    ocupacion_operador_2 = ocupacion_operador_2 + t_o

    vector_cola.append({'Minuto': t_l, 'Cliente': i, 'Estado':'Inicio'})
    vector_cola.append({'Minuto': h_s, 'Cliente': i, 'Estado':'Fin'})

#for i in range(0,total_eventos):
#    if vector_cola[i]['Estado'] == 'Inicio':
#        vector_if.append('I')
#    if vector_cola[i]['Estado'] == 'Fin':
#        vector_if.append('F')

#ordenar para luego agregar cola
vector_cola.sort(key=get_time)
cola = -1
cola_array = []
for i in range(0,2*total_eventos):
    if vector_cola[i]['Estado'] == 'Inicio':
        cola = cola+1
        vector_cola[i]['Cola'] = cola
        cola_array.append(cola)
        promedio_cola = cola*vector_cola[i]['Minuto']
    if vector_cola[i]['Estado'] == 'Fin':
        cola = cola-1
    #print(vector_cola[i])

#print(duplicates(vector_if, "F"))

#porcentaje de ocupacion de operador 2
Porcentaje_ocupacion = round((ocupacion_operador_2*100)/(vector_cola[len(vector_cola)-1]['Minuto'] - vector_cola[0]['Minuto']),2)
promedio_cola = round(promedio_cola/(vector_cola[len(vector_cola)-1]['Minuto'] - vector_cola[0]['Minuto']),2)

print(sum(cola_array)/len(cola_array))
print(Porcentaje_ocupacion)
print(promedio_cola )

plt.plot(cola_array)
ax = sns.displot(cola_array, rug=True)
# Out:
# 3.42
# 331.89
# 1.97
